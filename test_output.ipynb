# %%
import nn_utils
from ANN import NeuralNetwork
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\tongs\OneDrive\Desktop\TF_ANN_scratch\venv\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\tongs\OneDrive\Desktop\TF_ANN_scratch\venv\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\tongs\OneDrive\Desktop\TF_ANN_scratch\venv\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
(x_train, y_train), (x_test, y_test) = nn_utils.load_data()
nn_utils.plot_random_examples(x_train, y_train).show()

# %%
net = NeuralNetwork([784, 128, 128, 10])
net.info()
# Out:
# Input Features: 784
# Number of Classes: 10
# Hidden Layers:
# --------------
# Layer 1, Units 128
# Layer 2, Units 128
# --------------
# Number of parameters: 118282

# %%
batch_size = 120
epochs = 5
steps_per_epoch = int(x_train.shape[0]/ batch_size)
lr = 3e-3
history = net.train(x_train, y_train, x_test, y_test, epochs, steps_per_epoch, batch_size, lr )
# Out:
# Epoch 0...........Validation Accuracy:  0.8778
# Epoch 1...........Validation Accuracy:  0.8827
# Epoch 2...........Validation Accuracy:  0.8863
# Epoch 3...........Validation Accuracy:  0.89
# Epoch 4...........Validation Accuracy:  0.8882

# %%
nn_utils.plot_results(history=history).show()

# %%
preds = net.predict(x_test)
nn_utils.plot_random_examples(x_test, y_test, preds.numpy()).show()
